# %% [markdown]
# <div style="
#     background-color: #fff3cd;
#     border-left: 4px solid #f0ad4e;
#     padding: 10px 12px;
#     border-radius: 6px;
#     color: #664d03;
# ">
# 测试环境使用cst，Jupyter环境名是cellscape_test
# </div>

# %% [markdown]
# # 测试`labelme_to_masks`

# %%
import cellscape.datasets as dts
dts.labelme_to_masks(
    annotation_dir="library_backgrounds",
    image_dir="library_backgrounds",
    output_dir="library_backgrounds/mask",
    labels=["__ignore__", "_background_", "test"],
)
# Out:
# [LabelmeMaskResult(output_dir=PosixPath('library_backgrounds/mask'), sample_id='lib0', class_png_dir=PosixPath('library_backgrounds/mask/SegmentationClass/lib0'), class_png_files={'__ignore__': PosixPath('library_backgrounds/mask/SegmentationClass/lib0/-1___ignore__.png'), '_background_': PosixPath('library_backgrounds/mask/SegmentationClass/lib0/0__background_.png'), 'test': PosixPath('library_backgrounds/mask/SegmentationClass/lib0/1_test.png')}, class_npy=PosixPath('library_backgrounds/mask/SegmentationClassNpy/lib0.npy'), visualization_jpg=PosixPath('library_backgrounds/mask/SegmentationClassVisualization/lib0.jpg'), class_names_file=PosixPath('library_backgrounds/mask/class_names.txt'), labels=('__ignore__', '_background_', 'test'), class_ids={'__ignore__': -1, '_background_': 0, 'test': 1}),
#  LabelmeMaskResult(output_dir=PosixPath('library_backgrounds/mask'), sample_id='lib1', class_png_dir=PosixPath('library_backgrounds/mask/SegmentationClass/lib1'), class_png_files={'__ignore__': PosixPath('library_backgrounds/mask/SegmentationClass/lib1/-1___ignore__.png'), '_background_': PosixPath('library_backgrounds/mask/SegmentationClass/lib1/0__background_.png'), 'test': PosixPath('library_backgrounds/mask/SegmentationClass/lib1/1_test.png')}, class_npy=PosixPath('library_backgrounds/mask/SegmentationClassNpy/lib1.npy'), visualization_jpg=PosixPath('library_backgrounds/mask/SegmentationClassVisualization/lib1.jpg'), class_names_file=PosixPath('library_backgrounds/mask/class_names.txt'), labels=('__ignore__', '_background_', 'test'), class_ids={'__ignore__': -1, '_background_': 0, 'test': 1}),
#  LabelmeMaskResult(output_dir=PosixPath('library_backgrounds/mask'), sample_id='lib2', class_png_dir=PosixPath('library_backgrounds/mask/SegmentationClass/lib2'), class_png_files={'__ignore__': PosixPath('library_backgrounds/mask/SegmentationClass/lib2/-1___ignore__.png'), '_background_': PosixPath('library_backgrounds/mask/SegmentationClass/lib2/0__background_.png'), 'test': PosixPath('library_backgrounds/mask/SegmentationClass/lib2/1_test.png')}, class_npy=PosixPath('library_backgrounds/mask/SegmentationClassNpy/lib2.npy'), visualization_jpg=PosixPath('library_backgrounds/mask/SegmentationClassVisualization/lib2.jpg'), class_names_file=PosixPath('library_backgrounds/mask/class_names.txt'), labels=('__ignore__', '_background_', 'test'), class_ids={'__ignore__': -1, '_background_': 0, 'test': 1})]
